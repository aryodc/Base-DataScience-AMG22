# %%
import matplotlib.pyplot as plt

# %%
print("==SOAL NO 1==")
s2_a = 0
s2_b = 1
s2_c = 4
s2_d = 7
s2_e = 5
s2_f = 0
jml_s2 = s2_a + s2_b + s2_c + s2_d + s2_e + s2_f
print("Jumlah orang Tamat S2 : "+str (jml_s2))
s1_a = 4
s1_b = 12
s1_c = 6
s1_d = 13
s1_e = 14
s1_f = 0
jml_s1 = s1_a + s1_b + s1_c + s1_d + s1_e + s1_f
print("Jumlah orang Tamat S1 : "+str (jml_s1))
sma_a = 12
sma_b = 17
sma_c = 5
sma_d = 20
sma_e = 11
sma_f = 75
jml_sma = sma_a + sma_b + sma_c + sma_d + sma_e + sma_f
print("Jumlah orang Tamat SMA : "+str (jml_sma))
smp_a = 5
smp_b = 6
smp_c = 15
smp_d = 9
smp_e = 20
smp_f = 15
jml_smp = smp_a + smp_b + smp_c + smp_d + smp_e + smp_f
print("Jumlah orang Tamat SMP : "+str (jml_smp))
sd_a = 1
sd_b = 8
sd_c = 0
sd_d = 19
sd_e = 10
sd_f = 1
jml_sd = sd_a + sd_b + sd_c + sd_d + sd_e + sd_f
print("Jumlah orang Tamat SD : "+str (jml_sd))
td_a = 2
td_b = 14
td_c = 3
td_d = 10
td_e = 0
td_f = 1
jml_td = td_a + td_b + td_c + td_d + td_e + td_f
print("Jumlah orang Tidak Diketahui : "+str (jml_td))

print("")
print("==SOAL NO 2==")
indeks = 25
b_indeks = (jml_s2 / 100 )* indeks
print("Bobot indeks mutu pendidikan S2 : "+ str(b_indeks))
indeks = 20
b_indeks = (jml_s1 / 100 )* indeks
print("Bobot indeks mutu pendidikan S1 : "+ str(b_indeks))
indeks = 15
b_indeks = (jml_sma / 100 )* indeks
print("Bobot indeks mutu pendidikan SMA : "+ str(b_indeks))
indeks = 10
b_indeks = (jml_smp / 100 )* indeks
print("Bobot indeks mutu pendidikan SMP : "+ str(b_indeks))
indeks = 5
b_indeks = (jml_sd / 100 )* indeks
print("Bobot indeks mutu pendidikan SD : "+ str(b_indeks))
indeks = 3
b_indeks = (jml_td / 100 )* indeks
print("Bobot indeks mutu pendidikan SMA : "+ str(b_indeks))
print("")
print("==SOAL NO 3==")
print("Usia > 70")
b_indeks = 25
bb_indeks = (0 / 100) * b_indeks
print("Bobot indeks mutu pada usia 70 S2 : "+str(bb_indeks))
b_indeks = 20
bb_indeks1 = (4 / 100) * b_indeks
print("Bobot indeks mutu pada usia 70 S1 : "+str(bb_indeks1))
b_indeks = 15
bb_indeks2 = (12 / 100) * b_indeks
print("Bobot indeks mutu pada usia 70 SMA : "+str(bb_indeks2))
b_indeks = 10
bb_indeks3 = (5 / 100) * b_indeks
print("Bobot indeks mutu pada usia 70 SMP : "+str(bb_indeks3))
b_indeks = 5
bb_indeks4 = (1 / 100) * b_indeks
print("Bobot indeks mutu pada usia 70 SD : "+str(bb_indeks4))
b_indeks = 3
bb_indeks5 = (2 / 100) * b_indeks
print("Bobot indeks mutu pada usia 70 Tidak Diketahui : "+str(bb_indeks5))
jml_bi= bb_indeks + bb_indeks1 + bb_indeks2 + bb_indeks3 + bb_indeks4 + bb_indeks5
print("Jumlah bobot pada usia > 70 : "+ str(jml_bi))
print("___________________________________________________")

print("Usia > 60")
b_indeks = 25
bb_indeks = (1 / 100) * b_indeks
print("Bobot indeks mutu pada usia 60 S2 : "+str(bb_indeks))
b_indeks = 20
bb_indeks1 = (12 / 100) * b_indeks
print("Bobot indeks mutu pada usia 60 S1 : "+str(bb_indeks1))
b_indeks = 15
bb_indeks2 = (17 / 100) * b_indeks
print("Bobot indeks mutu pada usia 60 SMA : "+str(bb_indeks2))
b_indeks = 10
bb_indeks3 = (6 / 100) * b_indeks
print("Bobot indeks mutu pada usia 60 SMP : "+str(bb_indeks3))
b_indeks = 5
bb_indeks4 = (8 / 100) * b_indeks
print("Bobot indeks mutu pada usia 60 SD : "+str(bb_indeks4))
b_indeks = 3
bb_indeks5 = (14 / 100) * b_indeks
print("Bobot indeks mutu pada usia 60 Tidak Diketahui : "+str(bb_indeks5))
jml_bi= bb_indeks + bb_indeks1 + bb_indeks2 + bb_indeks3 + bb_indeks4 + bb_indeks5
print("Jumlah bobot pada usia > 60 : "+ str(jml_bi))
print("___________________________________________________")
print("Usia > 50")
b_indeks = 25
bb_indeks = (4 / 100) * b_indeks
print("Bobot indeks mutu pada usia 50 S2 : "+str(bb_indeks))
b_indeks = 20
bb_indeks1 = (6 / 100) * b_indeks
print("Bobot indeks mutu pada usia 50 S1 : "+str(bb_indeks1))
b_indeks = 15
bb_indeks2 = (5 / 100) * b_indeks
print("Bobot indeks mutu pada usia 50 SMA : "+str(bb_indeks2))
b_indeks = 10
bb_indeks3 = (15 / 100) * b_indeks
print("Bobot indeks mutu pada usia 50 SMP : "+str(bb_indeks3))
b_indeks = 5
bb_indeks4 = (0 / 100) * b_indeks
print("Bobot indeks mutu pada usia 50 SD : "+str(bb_indeks4))
b_indeks = 3
bb_indeks5 = (3 / 100) * b_indeks
print("Bobot indeks mutu pada usia 50 Tidak Diketahui : "+str(bb_indeks5))
jml_bi= bb_indeks + bb_indeks1 + bb_indeks2 + bb_indeks3 + bb_indeks4 + bb_indeks5
print("Jumlah bobot pada usia > 50 : "+ str(jml_bi))
print("___________________________________________________")

print("Usia > 40")
b_indeks = 25
bb_indeks = (7 / 100) * b_indeks
print("Bobot indeks mutu pada usia 40 S2 : "+str(bb_indeks))
b_indeks = 20
bb_indeks1 = (13 / 100) * b_indeks
print("Bobot indeks mutu pada usia 40 S1 : "+str(bb_indeks1))
b_indeks = 15
bb_indeks2 = (20 / 100) * b_indeks
print("Bobot indeks mutu pada usia 40 SMA : "+str(bb_indeks2))
b_indeks = 10
bb_indeks3 = (9 / 100) * b_indeks
print("Bobot indeks mutu pada usia 40 SMP : "+str(bb_indeks3))
b_indeks = 5
bb_indeks4 = (19 / 100) * b_indeks
print("Bobot indeks mutu pada usia 40 SD : "+str(bb_indeks4))
b_indeks = 3
bb_indeks5 = (10 / 100) * b_indeks
print("Bobot indeks mutu pada usia 40 Tidak Diketahui : "+str(bb_indeks5))
jml_bi= bb_indeks + bb_indeks1 + bb_indeks2 + bb_indeks3 + bb_indeks4 + bb_indeks5
print("Jumlah bobot pada usia > 40 : "+ str(jml_bi))
print("___________________________________________________")

print("Usia > 30")
b_indeks = 25
bb_indeks = (5 / 100) * b_indeks
print("Bobot indeks mutu pada usia 30 S2 : "+str(bb_indeks))
b_indeks = 20
bb_indeks1 = (14 / 100) * b_indeks
print("Bobot indeks mutu pada usia 30 S1 : "+str(bb_indeks1))
b_indeks = 15
bb_indeks2 = (11 / 100) * b_indeks
print("Bobot indeks mutu pada usia 30 SMA : "+str(bb_indeks2))
b_indeks = 10
bb_indeks3 = (20 / 100) * b_indeks
print("Bobot indeks mutu pada usia 30 SMP : "+str(bb_indeks3))
b_indeks = 5
bb_indeks4 = (10 / 100) * b_indeks
print("Bobot indeks mutu pada usia 30 SD : "+str(bb_indeks4))
b_indeks = 3
bb_indeks5 = (0 / 100) * b_indeks
print("Bobot indeks mutu pada usia 30 Tidak Diketahui : "+str(bb_indeks5))
jml_bi= bb_indeks + bb_indeks1 + bb_indeks2 + bb_indeks3 + bb_indeks4 + bb_indeks5
print("Jumlah bobot pada usia > 30 : "+ str(jml_bi))
print("___________________________________________________")

print("Usia > 20")
b_indeks = 25
bb_indeks = (0 / 100) * b_indeks
print("Bobot indeks mutu pada usia 20 S2 : "+str(bb_indeks))
b_indeks = 20
bb_indeks1 = (0 / 100) * b_indeks
print("Bobot indeks mutu pada usia 20 S1 : "+str(bb_indeks1))
b_indeks = 15
bb_indeks2 = (75 / 100) * b_indeks
print("Bobot indeks mutu pada usia 20 SMA : "+str(bb_indeks2))
b_indeks = 10
bb_indeks3 = (15 / 100) * b_indeks
print("Bobot indeks mutu pada usia 20 SMP : "+str(bb_indeks3))
b_indeks = 5
bb_indeks4 = (1 / 100) * b_indeks
print("Bobot indeks mutu pada usia 20 SD : "+str(bb_indeks4))
b_indeks = 3
bb_indeks5 = (1 / 100) * b_indeks
print("Bobot indeks mutu pada usia 20 Tidak Diketahui : "+str(bb_indeks5))
jml_bi= bb_indeks + bb_indeks1 + bb_indeks2 + bb_indeks3 + bb_indeks4 + bb_indeks5
print("Jumlah bobot pada usia > 20 : "+ str(jml_bi))
print("___________________________________________________")
print("")

print("==SOAL NO 4==")
min = [3.2099999999999995]
print("Maka Jumlah Pada Usia 70 dengan indeks mutu pendidikan paling kecil : "+str(min))

print("")
print("==SOAL NO 5==")
print("===== KESELURUHAN PENDIDIKAN =====")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
lulusan = ['S2','S1','SMA','SMP','SD','Tidak Diketahui']
jumlah = [17, 49, 140,70,39,30]
c = ['red','blue', 'green', 'yellow', 'gray', 'orange']
plt.title("Keseluruhan Pendidikan")
ax.bar(lulusan,jumlah,color = c )
plt.show()

#Pie chart
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
lulusan = ['S2','S1','SMA','SMP','SD','Tidak Diketahui']
jumlah = [17, 49, 140,70,39,30]
ax.pie(jumlah,labels=lulusan,autopct="%1.2f%%")
plt.title("Keseluruhan Pendidikan")
plt.show()

print("===== KESELURUHAN PADA USIA =====")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
lulusan = ['Usia > 70','Usia > 60','Usia > 50','Usia > 40','Usia > 30','Usia > 20']
jumlah = [24, 58, 33,78,60,92]
c = ['red','blue', 'green', 'yellow', 'gray', 'orange']
plt.title("Keseluruhan Pada Usia")
ax.bar(lulusan,jumlah,color = c )
plt.show()

#Pie chart
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
lulusan = ['Usia > 70','Usia > 60','Usia > 50','Usia > 40','Usia > 30','Usia > 20']
jumlah = [24, 58, 33,78,60,92]
ax.pie(jumlah,labels=lulusan,autopct="%1.2f%%")
plt.title("Keseluruhan Pada Usia")
plt.show()
# Out:
# ==SOAL NO 1==
# Jumlah orang Tamat S2 : 17
# Jumlah orang Tamat S1 : 49
# Jumlah orang Tamat SMA : 140
# Jumlah orang Tamat SMP : 70
# Jumlah orang Tamat SD : 39
# Jumlah orang Tidak Diketahui : 30
#
# ==SOAL NO 2==
# Bobot indeks mutu pendidikan S2 : 4.25
# Bobot indeks mutu pendidikan S1 : 9.8
# Bobot indeks mutu pendidikan SMA : 21.0
# Bobot indeks mutu pendidikan SMP : 7.0
# Bobot indeks mutu pendidikan SD : 1.9500000000000002
# Bobot indeks mutu pendidikan SMA : 0.8999999999999999
#
# ==SOAL NO 3==
# Usia > 70
# Bobot indeks mutu pada usia 70 S2 : 0.0
# Bobot indeks mutu pada usia 70 S1 : 0.8
# Bobot indeks mutu pada usia 70 SMA : 1.7999999999999998
# Bobot indeks mutu pada usia 70 SMP : 0.5
# Bobot indeks mutu pada usia 70 SD : 0.05
# Bobot indeks mutu pada usia 70 Tidak Diketahui : 0.06
# Jumlah bobot pada usia > 70 : 3.2099999999999995
# ___________________________________________________
# Usia > 60
# Bobot indeks mutu pada usia 60 S2 : 0.25
# ...
