# %%
import matplotlib.pyplot as plt

# %%
print("==SOAL NO 1==")
burger = 6
pizza = 3
dimsum = 4
ekkado = 4
milkshake = 2
eskrim = 5
jml1= burger + pizza + dimsum + ekkado + milkshake + eskrim
jml= ( burger * 24000) + (pizza * 52000) + (dimsum * 30000) + (ekkado * 7500) + (milkshake * 10000) + (eskrim * 15000)
print("Jumlah Makanan yang di pesan : "+str(jml1))
print("Jumlah semua Harga makanan yang di pesan Adalah : Rp."+ str(jml))

print("")
print("==SOAL NO 2==")
jml1= burger + pizza + dimsum + ekkado + milkshake + eskrim
print("Jumlah Makanan yang di pesan : "+str(jml1))
p_burger = burger / 24 * 100
print("Persentasi Burger : "+ str(p_burger))
p_pizza = pizza / 24 * 100
print("Persentasi Pizza : "+ str(p_pizza))
p_dimsum = dimsum / 24 * 100
print("Persentasi Dimsum : "+ str(p_dimsum))
p_ekkado = ekkado / 24 * 100
print("Persentasi Ekkado : "+ str(p_ekkado))
p_milkshake = milkshake / 24 * 100
print("Persentasi Milkshake : "+ str(p_milkshake))
p_eskrim = eskrim / 24 * 100
print("Persentasi Eskrim : "+ str(p_eskrim))

print("")
#Pie chart
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
lulusan = ['Burger','Pizza','Dimsum','Ekkado','Milkshake','Eskrim']
jumlah = [25.0,12.5,16.666666666666664,16.666666666666664,8.333333333333332,20.833333333333336]
ax.pie(jumlah,labels=lulusan,autopct="%1.2f%%")
plt.title("Persentase Pesanan dalam PieChart")
plt.show()

print("==SOAL NO 3==")
print("Pesanan Ahmad")
burger = 4
pizza = 2
jml_b = (0.70 * ((burger * 24000) + (pizza * 52000))) + (7.5 * 2000) - 5000
print("Jumlah Uang yang dibayar : "+str(jml_b))
kem = (200000 - jml_b)
print("Kembaliannya + gratis ongkir 5000 Adalah : "+str(kem))
print("=============")

print("Pesanan Beni")
dimsum = 3
eskrim = 1
milkshake = 2
jml_b = (0.70 * ((dimsum * 30000) + (eskrim * 15000) + (milkshake * 10000))) + (4 * 1800) - 5000
print("Jumlah yang harus di bayar : "+ str(jml_b))
kem = 150000 - jml_b
print("Kembaliannya + gratis ongkir 5000 Adalah : "+str(kem))
print("=============")

print("Pesanan Citra")
eskrim = 3
jml_b = (eskrim * 15000) + (8 * 2000) - 5000
print("Jumlah yang harus di bayar : "+ str(jml_b))
kem = 60000 - jml_b
print("Kembaliannya + gratis ongkir 5000 Adalah : "+str(kem))
print("=============")

print("Pesanan Dadang")
burger = 2
dimsum = 1
jml_b =(0.80 * ((burger * 24000) + (dimsum * 30000))) + (5 * 1800) - 5000
print("Jumlah yang harus di bayar : "+ str(jml_b))
kem = 100000 - jml_b
print("Kembaliannya + gratis ongkir 5000 Adalah : "+str(kem))
print("=============")

print("Pesanan Epen")
ekkado = 4
eskrim = 1
pizza = 1
jml_b = (0.70 *((ekkado * 7500) + (eskrim * 15000) + (pizza * 52000))) + (12 * 2200) - 5000
print("Jumlah yang harus di bayar : "+ str(jml_b))
kem = 100000 - jml_b
print("Kembaliannya + gratis ongkir 5000 Adalah : "+str(kem))
print("=============")
print("==SOAL NO 4==")
belanjaan = 150000
burger = 4
pizza = 2 
hasil = (0.30 * ((burger * 24000) + (pizza * 52000))) + 5000 
print("Maka jumlah potongan Ahmad : "+str(hasil))
dimsum = 3
eskrim = 1
milkshake = 2
hasil2 = (0.30 * ((dimsum * 30000) + (eskrim * 15000) + (milkshake * 10000))) + 5000
print("Maka jumlah potongan Beni : "+str(hasil2))
eskrim = 3
hasil3 = 5000
print("Maka jumlah potongan Citra : "+str(hasil3))
burger = 2
dimsum = 1
hasil4 = (0.20 * ((burger * 24000) + (dimsum * 30000))) + 5000
print("Maka jumlah potongan Dadang : "+str(hasil4))
ekkado = 4
eskrim = 1
pizza = 1
hasil5 = (0.30 * ((ekkado * 7500) + (eskrim * 15000) + (pizza * 52000))) + 5000
print("Maka jumlah potongan Epen : "+str(hasil5))
hasil6 = hasil + hasil2 + hasil3 + hasil4 + hasil5
print("Maka Jumlah potongan keseluruhan Adalah : "+str(hasil6))

print("==SOAL NO 5==")
jarak_a = 7.5
ongkos_a = 2000
jarak_b = 4
ongkos_b = 1800
jarak_c = 8
ongkos_c = 2000
jarak_d = 5
ongkos_d = 1800
jarak_e = 12
ongkos_e = 2200
hasil = (jarak_a * ongkos_a) + (jarak_b * ongkos_b) + (jarak_c * ongkos_c) + (jarak_d * ongkos_d) + (jarak_e * ongkos_e)
print("Maka Hasilnya adalah : "+str(hasil))
# Out:
# ==SOAL NO 1==
# Jumlah Makanan yang di pesan : 24
# Jumlah semua Harga makanan yang di pesan Adalah : Rp.545000
#
# ==SOAL NO 2==
# Jumlah Makanan yang di pesan : 24
# Persentasi Burger : 25.0
# Persentasi Pizza : 12.5
# Persentasi Dimsum : 16.666666666666664
# Persentasi Ekkado : 16.666666666666664
# Persentasi Milkshake : 8.333333333333332
# Persentasi Eskrim : 20.833333333333336
# ==SOAL NO 3==
# Pesanan Ahmad
# Jumlah Uang yang dibayar : 150000.0
# Kembaliannya + gratis ongkir 5000 Adalah : 50000.0
# ...
# Pesanan Beni
# Jumlah yang harus di bayar : 89700.0
# Kembaliannya + gratis ongkir 5000 Adalah : 60300.0
# ...
# Pesanan Citra
# Jumlah yang harus di bayar : 56000
# Kembaliannya + gratis ongkir 5000 Adalah : 4000
# ...
# Pesanan Dadang
# Jumlah yang harus di bayar : 66400.0
# Kembaliannya + gratis ongkir 5000 Adalah : 33600.0
# ...
# Pesanan Epen
# Jumlah yang harus di bayar : 89300.0
# Kembaliannya + gratis ongkir 5000 Adalah : 10700.0
# ...
# ==SOAL NO 4==
# Maka jumlah potongan Ahmad : 65000.0
# ...
