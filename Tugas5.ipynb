# %%
import matplotlib.pyplot as plt

# %%
print("==SOAL NO 1==")
kary = 20
gaji = 300000
asuransi = 75000
hasil = (gaji * kary) + (asuransi * kary)
print("Maka Pengeluaran gaji + asuransi A-xis : "+str(hasil))
kary = 14
gaji = 360000
asuransi = 75000
hasil = (gaji * kary) + (asuransi * kary)
print("Maka Pengeluaran gaji + asuransi B-log : "+str(hasil))
kary = 28
gaji = 475000
asuransi = 75000
hasil = (gaji * kary) + (asuransi * kary)
print("Maka Pengeluaran gaji + asuransi C-in : "+str(hasil))
kary = 42
gaji = 580000
asuransi = 75000
hasil = (gaji * kary) + (asuransi * kary)
print("Maka Pengeluaran gaji + asuransi D-namic : "+str(hasil))
kary = 18
gaji = 400000
asuransi = 75000
hasil = (gaji * kary) + (asuransi * kary)
print("Maka Pengeluaran gaji + asuransi E-psilon : "+str(hasil))

print("==SOAL NO 2==")
utang1 = 0.08
utang2 = 0.04
utang3 = 0.12
utang4 = 0.11
utang5 = 0.03
pajak = 0.03

laba_a = 32500000
laba_b = 31000000
laba_c = 42000000
laba_d = 51500000
laba_e = 27000000

hasil = (laba_a * pajak) + (utang1 * 280000000)
print("Maka total pajak dan hutang A : "+str(hasil))
hasil = (laba_b * pajak) + (utang2 * 310000000)
print("Maka total pajak dan hutang B : "+str(hasil))
hasil = (laba_c * pajak) + (utang3 * 420000000)
print("Maka total pajak dan hutang C : "+str(hasil))
hasil = (laba_d * pajak) + (utang4 * 550000000)
print("Maka total pajak dan hutang D : "+str(hasil))
hasil = (laba_e * pajak) + (utang5 * 340000000)
print("Maka total pajak dan hutang E : "+str(hasil))

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['A-xis','B-Log','C-in','D-Namic','E-Psilon']
jumlah = [23375000.0, 13330000.0, 51660000.0,62045000.0,11010000.0]
c = ['red','blue', 'green', 'yellow', 'gray']
plt.title("Garik Bar Pajak dan Utang Setiap perusahaan")
ax.bar(eskul,jumlah,color = c )
plt.show()

#Pie chart
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ['A-xis','B-Log','C-in','D-Namic','E-Psilon']
jumlah = [23375000.0, 13330000.0, 51660000.0,62045000.0,11010000.0]
ax.pie(jumlah,labels=eskul,autopct="%1.2f%%")
plt.title("Garik Piechart Pajak dan Utang Setiap perusahaan")
plt.show()

print("==SOAL NO 3==")
asseta = 280000000
assetb = 310000000
assetc = 420000000
assetd = 550000000
assete = 340000000
csr = 0.025
csr2 = 0.035
hasil= asseta * csr
print("Maka CSR perusahaan a Adalah : "+str(hasil))
hasil= assetb * csr2
print("Maka CSR perusahaan b Adalah : "+str(hasil))
hasil= assetc * csr2
print("Maka CSR perusahaan c Adalah : "+str(hasil))
hasil= assetd * csr2
print("Maka CSR perusahaan d Adalah : "+str(hasil))
hasil= assete * csr2
print("Maka CSR perusahaan e Adalah : "+str(hasil))

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['A-xis','B-Log','C-in','D-Namic','E-Psilon']
jumlah = [7000000.0, 10850000.000000002, 14700000.000000002,19250000.0,11900000.000000002]
c = ['red','blue', 'green', 'yellow', 'gray']
plt.title("Garik Bar CSR Setiap perusahaan")
ax.bar(eskul,jumlah,color = c )
plt.show()
#Pie chart
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ['A-xis','B-Log','C-in','D-Namic','E-Psilon']
jumlah = [7000000.0, 10850000.000000002, 14700000.000000002,19250000.0,11900000.000000002]
ax.pie(jumlah,labels=eskul,autopct="%1.2f%%")
plt.title("Garik Bar CSR Setiap perusahaan")
plt.show()


print("==SOAL NO 4==")
hasil2 = laba_a * 12
print("Laba A-xis pertahun : "+str(hasil2))
hasil3 = laba_b * 12
print("Laba B-log pertahun : "+str(hasil3))
hasil4 = laba_c * 12
print("Laba C-in pertahun : "+str(hasil4))
hasil5 = laba_d * 12
print("Laba D-Namic pertahun : "+str(hasil5))
hasil6 = laba_e * 12
print("Laba E-psilon pertahun : "+str(hasil6))
hasil1 = hasil2 + hasil3 + hasil4 + hasil5 + hasil6
print("Total laba semua perusahaan selama 1 tahun : "+str(hasil1))

print("==SOAL NO 5==")
laba_a = 32500000
laba_b = 31000000
laba_c = 42000000
laba_d = 51500000
laba_e = 27000000
tahun = 12
axis = 20
blog = 14
cin = 28
dnamic = 42
epsilon = 18

hasil = (laba_a * tahun) - csr * asseta - (7500000 * tahun) - 23375000.0
print("Total pendapatan Bersih Pertahun perusahaan a : "+str(hasil))
hasil = (laba_b * tahun) - csr2 * assetb - (6090000 * tahun) - 13330000.0
print("Total pendapatan Bersih Pertahun perusahaan b : "+str(hasil))
hasil = (laba_c * tahun) - csr2 * assetc - (15400000 * tahun) - 51660000.0
print("Total pendapatan Bersih Pertahun perusahaan c : "+str(hasil))
hasil = (laba_d * tahun) - csr2 * assetd - (27510000 * tahun) - 62045000.0
print("Total pendapatan Bersih Pertahun perusahaan d : "+str(hasil))
hasil = (laba_e * tahun) - csr2 * assete - (8550000 * tahun) - 11010000.0
print("Total pendapatan Bersih Pertahun perusahaan e : "+str(hasil))

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['A-xis','B-Log','C-in','D-Namic','E-Psilon']
jumlah = [269625000.0, 274740000.0, 252840000.0,206585000.0,198490000.0]
c = ['red','blue', 'green', 'yellow', 'gray']
plt.title("Grafik Bar Pendapatan bersih Setiap perusahaan")
ax.bar(eskul,jumlah,color = c )
plt.show()
#Pie chart
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ['A-xis','B-Log','C-in','D-Namic','E-Psilon']
jumlah = [269625000.0, 274740000.0, 252840000.0,206585000.0,198490000.0]
ax.pie(jumlah,labels=eskul,autopct="%1.2f%%")
plt.title("Garik Bar CSR Setiap perusahaan")
plt.show()
# Out:
# ==SOAL NO 1==
# Maka Pengeluaran gaji + asuransi A-xis : 7500000
# Maka Pengeluaran gaji + asuransi B-log : 6090000
# Maka Pengeluaran gaji + asuransi C-in : 15400000
# Maka Pengeluaran gaji + asuransi D-namic : 27510000
# Maka Pengeluaran gaji + asuransi E-psilon : 8550000
# ==SOAL NO 2==
# Maka total pajak dan hutang A : 23375000.0
# Maka total pajak dan hutang B : 13330000.0
# Maka total pajak dan hutang C : 51660000.0
# Maka total pajak dan hutang D : 62045000.0
# Maka total pajak dan hutang E : 11010000.0
# ==SOAL NO 3==
# Maka CSR perusahaan a Adalah : 7000000.0
# Maka CSR perusahaan b Adalah : 10850000.000000002
# Maka CSR perusahaan c Adalah : 14700000.000000002
# Maka CSR perusahaan d Adalah : 19250000.0
# Maka CSR perusahaan e Adalah : 11900000.000000002
# ==SOAL NO 4==
# Laba A-xis pertahun : 390000000
# Laba B-log pertahun : 372000000
# Laba C-in pertahun : 504000000
# Laba D-Namic pertahun : 618000000
# Laba E-psilon pertahun : 324000000
# ...
