# %%
import matplotlib.pyplot as plt

# %%
print("==SOAL NO 1==")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLLY','KESENIAN','ROHIS']
jumlah = [5, 18, 30,7,16,19,12]
c = ['red','blue', 'green', 'yellow', 'gray', 'orange','purple']
plt.title("")
ax.bar(eskul,jumlah,color = c )
plt.show()

print("")
print("==SOAL NO 2==")
p10 = 5
p11 = 21
p12 = 6
jml = p10 + p11 + p12
print("Jumlah yang mengikuti PASKIBRA : "+ str(jml))
pmr10 = 18
pmr11 = 4
pmr12 = 12
jml = pmr10 + pmr11 + pmr12
print("Jumlah yang mengikuti PMR : "+ str(jml))
pra10 = 30
pra11 = 8
pra12 = 24
jml = pra10 + pra11 + pra12
print("Jumlah yang mengikuti PRAMUKA : "+ str(jml))
fut10 = 7
fut11 = 29
fut12 = 15
jml = fut10 + fut11 + fut12
print("Jumlah yang mengikuti FUTSAL : "+ str(jml))
vol10 = 16
vol11 = 10
vol12 = 12
jml = vol10 + vol11 + vol12
print("Jumlah yang mengikuti VOLLY : "+ str(jml))
kes10 = 19
kes11 = 18
kes12 = 4
jml = kes10 + kes11 + kes12
print("Jumlah yang mengikuti KESENIAN : "+ str(jml))
roh10 = 12
roh11 = 10
roh12 = 7
jml = roh10 + roh11 + roh12
print("Jumlah yang mengikuti ROHIS : "+ str(jml))
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLLY','KESENIAN','ROHIS']
jumlah = [32, 34, 62,51,38,41,29]
c = ['red','blue', 'green', 'yellow', 'gray', 'orange','purple']
plt.title("JUMLAH SISWA YANG MENGIKUTI SETIAP ESKUL")
ax.bar(eskul,jumlah,color = c )
plt.show()

print("")
print("==SOAL NO 3==")
fut10 = 7
fut11 = 29
fut12 = 15
vol10 = 16
vol11 = 10
vol12 = 12
jml = fut10+fut11+fut12+vol10+vol11+vol12
print("Jumlah yang mengikuti olah raga : "+ str(jml))
fut10 = 107
fut11 = 100
fut12 = 80
jml = fut10+fut11+fut12 - 89
print("Jumlah yang mengikuti eskul : "+ str(jml))
fut10 = 17
fut11 = 8
fut12 = 20
jml = fut10+fut11+fut12
print("Jumlah yang mengikuti tidak mengikuti : "+ str(jml))
a = 89
b = 198
c = 45 
pers = a * 100 / 332
pers2 = b * 100 / 332
pers3 = c * 100 / 332
print("Persentaseu Pada Olahraga : "+ str(pers))
print("Persentaseu Pada mengikuti : "+ str(pers2))
print("Persentaseu Pada tidak mengikuti : "+ str(pers3))
jml_pers=pers+pers2+pers3
print("Hasil persentasi nya adalah : " +str(jml_pers))

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['OLAHRAGA','MENGIKUTI','TIDAK MENGIKUTI']
jumlah = [89,198,45]
c = ['red','blue', 'green']
plt.title("DATA PERSENTASEU")
ax.bar(eskul,jumlah,color = c )
plt.show()
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ['OLAHRAGA','MENGIKUTI','TIDAK MENGIKUTI']
jumlah = [89,198,45]
ax.pie(jumlah,labels=eskul,autopct="%1.2f%%")
plt.title("DATA PERSENTASEU")
plt.show()
print("=========================")
print("==SOAL NO 4==")
td = 17
td1 = 8 
td2 = 20
jml_td1 = td + td1 + td2
print("Jumlah siswa yang tidak mengikuti ESKUL : "+ str(jml_td1))
indeks = 45
b_indeks = (td / indeks )* 100
print("Persentaseu siswa Tidak mengikuti Kelas 10 : "+ str(b_indeks))
indeks = 45
b_indeks2 = (td1 / indeks )* 100
print("Persentaseu siswa Tidak mengikuti Kelas 11 : "+ str(b_indeks2))
indeks = 45
b_indeks3 = (td2 / indeks )* 100
print("Persentaseu siswa Tidak mengikuti Kelas 12 : "+ str(b_indeks3))
jml_pers=b_indeks+b_indeks2+b_indeks3
print("Maka hasil persentasinya adalah : "+str(jml_pers))



#Pie chart
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
lulusan = ['KELAS 10','KELAS 11','KELAS 12']
jumlah = [37.77777777777778,17.77777777777778,44.44444444444444]
ax.pie(jumlah,labels=lulusan,autopct="%1.2f%%")
plt.title("Data Keseluruhan Yang Tidak Mengikuti Eskul")
plt.show()

print("==SOAL NO 5==")
print("")
m_a = 5
m_b = 18
m_c = 30
m_d = 7
m_e = 16
m_f = 19
m_g = 12
jml= m_a + m_b + m_c + m_d+m_e+m_f+m_g
print("jumlah yang mengikuti eskul kelas 10 : "+ str(jml))

m_a = 21
m_b = 4
m_c = 8
m_d = 29
m_e = 10
m_f = 18
m_g = 10
jml= m_a + m_b + m_c + m_d+m_e+m_f+m_g
print("jumlah yang mengikuti eskul kelas 11 : "+ str(jml))

m_a = 6
m_b = 12
m_c = 24
m_d = 15
m_e = 12
m_f = 4
m_g = 7
jml= m_a + m_b + m_c + m_d+m_e+m_f+m_g
print("jumlah yang mengikuti eskul kelas 12 : "+ str(jml))

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLLY','KESENIAN','ROHIS']
jumlah = [5, 18, 30,7,16,19,12]
c = ['red','blue', 'green', 'yellow', 'gray', 'orange','purple']
plt.title("DATA YANG MENGIKUTI ESKUL KELAS 10")
ax.bar(eskul,jumlah,color = c )
plt.show()
#Pie chart
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLLY','KESENIAN','ROHIS']
jumlah = [5, 18, 30,7,16,19,12]
ax.pie(jumlah,labels=eskul,autopct="%1.2f%%")
plt.title("DATA YANG MENGIKUTI ESKUL KELAS 10")
plt.show()
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLLY','KESENIAN','ROHIS']
jumlah = [21, 4,8,29,10,18,10]
c = ['red','blue', 'green', 'yellow', 'gray', 'orange','purple']
plt.title("DATA YANG MENGIKUTI ESKUL KELAS 11")
ax.bar(eskul,jumlah,color = c )
plt.show()
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLLY','KESENIAN','ROHIS']
jumlah = [21, 4,8,29,10,18,10]
ax.pie(jumlah,labels=eskul,autopct="%1.2f%%")
plt.title("DATA YANG MENGIKUTI ESKUL KELAS 11")
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLLY','KESENIAN','ROHIS']
jumlah = [6, 12,24,15,12,4,7]
c = ['red','blue', 'green', 'yellow', 'gray', 'orange','purple']
plt.title("DATA YANG MENGIKUTI ESKUL KELAS 12")
ax.bar(eskul,jumlah,color = c )
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLLY','KESENIAN','ROHIS']
jumlah = [6, 12,24,15,12,4,7]
ax.pie(jumlah,labels=eskul,autopct="%1.2f%%")
plt.title("DATA YANG MENGIKUTI ESKUL KELAS 12")
plt.show()
# Out:
# ==SOAL NO 1==
# ==SOAL NO 2==
# Jumlah yang mengikuti PASKIBRA : 32
# Jumlah yang mengikuti PMR : 34
# Jumlah yang mengikuti PRAMUKA : 62
# Jumlah yang mengikuti FUTSAL : 51
# Jumlah yang mengikuti VOLLY : 38
# Jumlah yang mengikuti KESENIAN : 41
# Jumlah yang mengikuti ROHIS : 29
# ==SOAL NO 3==
# Jumlah yang mengikuti olah raga : 89
# Jumlah yang mengikuti eskul : 198
# Jumlah yang mengikuti tidak mengikuti : 45
# Persentaseu Pada Olahraga : 26.80722891566265
# Persentaseu Pada mengikuti : 59.63855421686747
# Persentaseu Pada tidak mengikuti : 13.55421686746988
# Hasil persentasi nya adalah : 100.0
# ...
# ==SOAL NO 4==
# Jumlah siswa yang tidak mengikuti ESKUL : 45
# Persentaseu siswa Tidak mengikuti Kelas 10 : 37.77777777777778
# Persentaseu siswa Tidak mengikuti Kelas 11 : 17.77777777777778
# Persentaseu siswa Tidak mengikuti Kelas 12 : 44.44444444444444
# Maka hasil persentasinya adalah : 100.0
# ==SOAL NO 5==
#
# jumlah yang mengikuti eskul kelas 10 : 107
# ...
